# %%
import os
import pandas as pd
print(os.listdir('/'))
df=pd.read_csv("book1.csv")
print(df)
for i,col in enumerate(df.columns,start=1):
    print(i,':',col)
print(df.shape)#no rows and coloumns
print(df.head())
print(df["rollno"].value_counts())
print(df["rollno"].isnull().sum())
# Out:
# ['$Recycle.Bin', '$WinREAgent', '.GamingRoot', 'Documents and Settings', 'DumpStack.log.tmp', 'hiberfil.sys', 'hp', 'inetpub', 'java', 'OneDriveTemp', 'pagefile.sys', 'PerfLogs', 'Program Files', 'Program Files (x86)', 'ProgramData', 'Recovery', 'swapfile.sys', 'swsetup', 'System Volume Information', 'System.Sav', 'tmp', 'Users', 'Voiceover', 'Windows', 'XboxGames']
#    sno  rollno      name  marks    Dep  Pass
# 0    1     111  Shashank   78.3    CSE     0
# 1    2     112    Manish   66.0   AIDS     1
# 2    3     113   Hemanth   56.3    CSE     0
# 3    4     114    Ishwak   89.3    CSE     0
# 4    5     115     Pavan   55.0    CSE     1
# 5    6     116   Karthik   92.0  CSEIT     1
# 6    7     117     Yuvan  100.0    CSE     1
# 1 : sno
# 2 : rollno
# 3 : name
# 4 : marks
# 5 : Dep
# 6 : Pass
# (7, 6)
#    sno  rollno      name  marks   Dep  Pass
# 0    1     111  Shashank   78.3   CSE     0
# 1    2     112    Manish   66.0  AIDS     1
# ...
